# %% [markdown]
# # Dataset from Guillaume

# %%
using CSV, DataFrames, Plots, cmdstan_utils, DelimitedFiles
plotlyjs()
# Out:
# Plots.PlotlyJSBackend()

# %% [markdown]
# Import file containing all mapped ~17K TSSs they tested in the paper to 2,387 operons in E. coli. He matched TSSs with an operon if the operon was within 500bp downstream (smaller margins possible). The data frame contains the position and strength of the TSS/promoter, whether they considered the TSS 'active' or 'inactive', and the coordinates of the operon (left, right, strand).

# %%
df = CSV.read("../data/gen2/tss_operon_regulation.txt")
names(df)
# Out:
# 9-element Array{Symbol,1}:
#  :tss_name
#  :tss_strand
#  :tss_position
#  :prom_expression
#  :active
#  :left
#  :right
#  :operon
#  :strand

# %% [markdown]
# ## Update genome positions

# %% [markdown]
# An old E.coli genome is used for this dataset, so first we have to update all the positions from the old data set to the new one. Therefore we use the [Ecocyc tool](https://ecocyc.org/ECOLI/map-seq-coords-form?chromosome=COLI-K12), and make sure that the old format is U00096.2 and the new one is U00096.3.

# %%
old_pos = df.tss_position
old_pos_arr = convert(Array{Int64, 1}, old_pos)
writedlm("position_list.txt", old_pos_arr)

# %%
new_pos = readdlm("new_positions.txt")
new_pos = convert(Array{Int64, 1}, new_pos[:, 1])
df.new_tss_position = new_pos;

# %%
df2 = CSV.read("../data/gen2/scanning_mutagenesis_data.txt", missingstring="NA")
df2 = df2[findall(x -> ~ismissing(x), df2.tss_position), :];

# %%
old_pos2 = df2.tss_position
old_pos_arr2 = convert(Array{Int64, 1}, old_pos2)
writedlm("position_list2.txt", old_pos_arr2)

# %%
new_pos2 = readdlm("new_positions2.txt")
new_pos2 = convert(Array{Int64, 1}, new_pos2[:, 1])
df2.new_tss_position = new_pos2;
df2 = df2[findall(x -> ~ismissing(x), df2.scramble_start), :];
df2 = df2[findall(x -> ~ismissing(x), df2.relative_exp), :];

# %% [markdown]
# Let's look at all the column names in the mutagenesis file.

# %%
names(df2)
# Out:
# 18-element Array{Symbol,1}:
#  :name
#  :tss_name
#  :tss_position
#  :strand
#  :scramble_start
#  :scramble_end
#  :prom_left_position
#  :prom_right_position
#  :scramble_start_pos
#  :scramble_end_pos
#  :scramble_pos_rel_tss
#  :expn_med_fitted
#  :unscrambled_exp
#  :relative_exp
#  :num_barcodes_integrated
#  :category
#  :active
#  :new_tss_position

# %% [markdown]
# ## Load on Reg-Seq transcription start sites

# %% [markdown]
# Many genes in the RegSeq list are actually part of an operon. So for every gene, which is not in the list, I checked if it is part of an operon which is in the list. Therefore we have the dictionary below, which maps the RegSeq gene names to the operon names in Guillaume's data set. Some genes are also known under a different name, which can be found on EcoCyc.

# %%
regseq_tss = CSV.read("../data/RegSeq/wtsequences.csv")
regseq_tss[!, :start_site] = convert.(Int64, regseq_tss[!,:start_site]);

# %%
gene_to_operon = Dict(
    "ecnB" => "ecnAB",
    "fdoH" => "fdoGHI-fdhE",
    "dinJ" => "dinJ-yafQ",
    "ompR" => "ompR-envZ",
    "dicB" => "dicB-ydfDE-insD-intQ",
    "dicC" => "dicC-ydfXW",
    "xylA" => "xylAB",
    "xylF" => "xylFGHR",
    "tar" => "tar-tap-cheRBYZ",
    "mscM" => "psd-mscM",
    "rspA" => "rspAB",
    "poxB" => "poxB-ltaE-ybjT",
    "yehT" => "yehUT",
    "yehU" => "yehUT",
    "yggW" => "yggSTU-rdgB-yggW",
    "ydjA" => "ydjA-selD-topB",
    "ybeZ" => "ybeZYX-lnt",
    "minC" => "minCDE",
    "hicB" => "hicAB",
    "rcsF" => "rcsF-trmO",
    "pcm" => "umpG-pcm",
    "ybiP"=>"opgE",
    "yecE" => "yecDE",
    "yajL" => "panE-yajL",
    "modE" => "modEF",
    "ymgG" => "ymgGD",
    "hslU" => "hslVU",
    "ydhO" => "mepH",
    "fdhE" => "fdoGHI-fdhE",
    "htrB" => "lpxL",
    "yagH" => "yagGH",
    "mtgA" => "elbB-mtgA",
    "ybjT" => "poxB-ltaE-ybjT",
    "ykgE" => "ykgEFG",
    "thiM" => "thiMD",
    "sdaB" => "sdaCB",
    "fdoH" => "fdoGHI-fdhE",
    "leuABCD" => "leuLABCD",
    "araAB" => "araBAD",
    "WaaA-coaD" => "waaA-coaD",
    "acuI" => "yhdH",
    "dnaE_start2" => "bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE",
    "dnaE_start1" => "bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE",
    "rlmC" => "ybjO-rlmC"
    
)
# Out:
# Dict{String,String} with 43 entries:
#   "ompR"        => "ompR-envZ"
#   "poxB"        => "poxB-ltaE-ybjT"
#   "pcm"         => "umpG-pcm"
#   "yehT"        => "yehUT"
#   "dnaE_start1" => "bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE"
#   "modE"        => "modEF"
#   "tar"         => "tar-tap-cheRBYZ"
#   "dinJ"        => "dinJ-yafQ"
#   "ymgG"        => "ymgGD"
#   "ecnB"        => "ecnAB"
#   "ybeZ"        => "ybeZYX-lnt"
#   "rspA"        => "rspAB"
#   "mtgA"        => "elbB-mtgA"
#   "ydhO"        => "mepH"
#   "minC"        => "minCDE"
#   "ykgE"        => "ykgEFG"
#   "yagH"        => "yagGH"
#   "fdoH"        => "fdoGHI-fdhE"
#   "acuI"        => "yhdH"
#   "yggW"        => "yggSTU-rdgB-yggW"
#   "leuABCD"     => "leuLABCD"
#   "rcsF"        => "rcsF-trmO"
#   "ybjT"        => "poxB-ltaE-ybjT"
#   "mscM"        => "psd-mscM"
#   "yajL"        => "panE-yajL"
#   ⋮             => ⋮

# %% [markdown]
# Now we can compare the transcription start sites for each promoter that is present in both data sets. For now we are just looking for matching (or very close) TSS, which in this case is every TSS within 10 bp. Later we can go through other cases as well.

# %%
# Array to store all differences in TSS
differences = Int64[]

# Array to store the TSS for matching genes
positions = Int64[]

# Get gene names which are part of operons
gene_keys = collect(keys(gene_to_operon))

# Store genes which are not in Guillaume's data set
found_none = String[]

# Store TSSs which are close to RegSeq TSSs
exact_match = Int64[]

# 
unique_operons = df.operon |> unique

for gene in regseq_tss.name
    if gene in unique_operons
        println("$gene is in the operon list.")
        
        reqseq_start = regseq_tss[regseq_tss.name.== gene, :start_site][1]
        guillaume_start = df[df.operon .== gene, :new_tss_position]
        
        println("RegSeq TSS: ", reqseq_start)
        println("Guillaume TSS: ", guillaume_start)
        
        diffs = guillaume_start .- reqseq_start
        
        println("Differences in start sites: ", diffs)
        
        push!(differences, diffs...)
        push!(positions, guillaume_start...)
        
        println()
        
        exact = findall(x->abs(x - reqseq_start) <= 10, guillaume_start)
        for x in exact
            push!(exact_match, guillaume_start[x]...)
        end
        
    elseif gene in gene_keys
        lab = gene_to_operon[gene]
        
        println("$gene is in the operon list for operon $lab.")
        
        reqseq_start = regseq_tss[regseq_tss.name.== gene, :start_site][1]
        guillaume_start = df[df.operon .== lab, :new_tss_position]
        
        println("RegSeq TSS: ", reqseq_start)
        println("Guillaume TSS: ", guillaume_start)
        
        diffs = guillaume_start .- reqseq_start
        
        println("Differences in start sites: ", diffs)
        
        push!(differences, diffs...)
        push!(positions, guillaume_start...)
        
        exact = findall(x->abs(x - reqseq_start) <= 10, guillaume_start)
        for x in exact
            push!(exact_match, guillaume_start[x]...)
        end

        println()
    else
        push!(found_none, gene)
    end
end
println("Found no operon for genes $found_none")
# Out:
# fdoH is in the operon list for operon fdoGHI-fdhE.
# RegSeq TSS: 4085867
# Guillaume TSS: [4085961]
# Differences in start sites: [94]
#
# sdaB is in the operon list for operon sdaCB.
# RegSeq TSS: 2928035
# Guillaume TSS: [2927935, 2927935, 2928103, 2928035]
# Differences in start sites: [-100, -100, 68, 0]
#
# thiM is in the operon list for operon thiMD.
# RegSeq TSS: 2185451
# Guillaume TSS: [2185450]
# Differences in start sites: [-1]
#
# ykgE is in the operon list for operon ykgEFG.
# RegSeq TSS: 321511
# Guillaume TSS: [321511, 321481, 321537]
# Differences in start sites: [0, -30, 26]
#
# sdiA is in the operon list.
# RegSeq TSS: 1996867
# Guillaume TSS: [1996851]
# Differences in start sites: [-16]
#
# yqhC is in the operon list.
# RegSeq TSS: 3155262
# Guillaume TSS: [3155384]
# Differences in start sites: [122]
#
# ybjT is in the operon list for operon poxB-ltaE-ybjT.
# RegSeq TSS: 909320
# Guillaume TSS: [911075]
# Differences in start sites: [1755]
#
# mtgA is in the operon list for operon elbB-mtgA.
# RegSeq TSS: 3350504
# Guillaume TSS: [3350559, 3350497]
# Differences in start sites: [55, -7]
#
# aphA is in the operon list.
# RegSeq TSS: 4269355
# Guillaume TSS: [4269355]
# Differences in start sites: [0]
#
# bdcR is in the operon list.
# RegSeq TSS: 4474096
# Guillaume TSS: [4474096, 4473676]
# Differences in start sites: [0, -420]
#
# yncD is in the operon list.
# RegSeq TSS: 1523276
# Guillaume TSS: [1523276, 1523094, 1523157]
# Differences in start sites: [0, -182, -119]
#
# yagH is in the operon list for operon yagGH.
# RegSeq TSS: 285350
# Guillaume TSS: [285207, 285271, 285350]
# Differences in start sites: [-143, -79, 0]
#
# eco is in the operon list.
# RegSeq TSS: 2303797
# Guillaume TSS: [2303797, 2303851]
# Differences in start sites: [0, 54]
#
# htrB is in the operon list for operon lpxL.
# RegSeq TSS: 1116709
# Guillaume TSS: [1116709]
# Differences in start sites: [0]
#
# iap is in the operon list.
# RegSeq TSS: 2876547
# Guillaume TSS: [2876107, 2876536]
# Differences in start sites: [-440, -11]
#
# ygjP is in the operon list.
# RegSeq TSS: 3235915
# Guillaume TSS: [3235904]
# Differences in start sites: [-11]
#
# yedK is in the operon list.
# RegSeq TSS: 2009776
# Guillaume TSS: [2009802, 2009515, 2009631]
# Differences in start sites: [26, -261, -145]
#
# aegA is in the operon list.
# RegSeq TSS: 2585570
# Guillaume TSS: [2585567]
# Differences in start sites: [-3]
#
# dusC is in the operon list.
# RegSeq TSS: 2230395
# Guillaume TSS: [2230395, 2230460, 2230485]
# Differences in start sites: [0, 65, 90]
#
# fdhE is in the operon list for operon fdoGHI-fdhE.
# RegSeq TSS: 4081359
# Guillaume TSS: [4085961]
# Differences in start sites: [4602]
#
# dnaE_start1 is in the operon list for operon bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE.
# RegSeq TSS: 197026
# Guillaume TSS: [197586, 197730, 197487, 208711, 197821, 197883]
# Differences in start sites: [560, 704, 461, 11685, 795, 857]
#
# dnaE_start2 is in the operon list for operon bamA-skp-lpxD-fabZ-lpxAB-rnhB-dnaE.
# RegSeq TSS: 197821
# Guillaume TSS: [197586, 197730, 197487, 208711, 197821, 197883]
# Differences in start sites: [-235, -91, -334, 10890, 0, 62]
#
# ycgB is in the operon list.
# RegSeq TSS: 1237285
# Guillaume TSS: [1237284]
# Differences in start sites: [-1]
#
# yehS is in the operon list.
# RegSeq TSS: 2212241
# Guillaume TSS: [2212226]
# Differences in start sites: [-15]
#
# yeiQ is in the operon list.
# RegSeq TSS: 2266214
# Guillaume TSS: [2265961, 2266164, 2266214]
# Differences in start sites: [-253, -50, 0]
#
# ydhO is in the operon list for operon mepH.
# RegSeq TSS: 1734357
# Guillaume TSS: [1734145, 1734206, 1734381, 1734357]
# Differences in start sites: [-212, -151, 24, 0]
#
# hslU is in the operon list for operon hslVU.
# RegSeq TSS: 4122354
# Guillaume TSS: [4122348, 4122310]
# Differences in start sites: [-6, -44]
#
# ymgG is in the operon list for operon ymgGD.
# RegSeq TSS: 1223097
# Guillaume TSS: [1223096]
# Differences in start sites: [-1]
#
# rlmA is in the operon list.
# RegSeq TSS: 1907086
# Guillaume TSS: [1907084, 1907139, 1907509]
# Differences in start sites: [-2, 53, 423]
#
# modE is in the operon list for operon modEF.
# RegSeq TSS: 794644
# Guillaume TSS: [795065, 794649]
# Differences in start sites: [421, 5]
#
# ycbZ is in the operon list.
# RegSeq TSS: 1018330
# Guillaume TSS: [1018460, 1018721, 1018323]
# Differences in start sites: [130, 391, -7]
#
# yajL is in the operon list for operon panE-yajL.
# RegSeq TSS: 443748
# Guillaume TSS: [444822, 444555]
# Differences in start sites: [1074, 807]
#
# yecE is in the operon list for operon yecDE.
# RegSeq TSS: 1950760
# Guillaume TSS: [1950636, 1950521, 1950760]
# Differences in start sites: [-124, -239, 0]
#
# ybiP is in the operon list for operon opgE.
# RegSeq TSS: 852626
# Guillaume TSS: [852713, 852626]
# Differences in start sites: [87, 0]
#
# ybjL is in the operon list.
# RegSeq TSS: 889945
# Guillaume TSS: [889992, 889938, 889941]
# Differences in start sites: [47, -7, -4]
#
# ygdH is in the operon list.
# RegSeq TSS: 2926272
# Guillaume TSS: [2926272]
# Differences in start sites: [0]
#
# pcm is in the operon list for operon umpG-pcm.
# RegSeq TSS: 2870686
# Guillaume TSS: [2870618, 2870686]
# Differences in start sites: [-68, 0]
#
# rcsF is in the operon list for operon rcsF-trmO.
# RegSeq TSS: 220022
# Guillaume TSS: [220072, 220022, 220386, 220265]
# Differences in start sites: [50, 0, 364, 243]
#
# sbcB is in the operon list.
# RegSeq TSS: 2082728
# Guillaume TSS: [2082724]
# Differences in start sites: [-4]
#
# ygeR is in the operon list.
# RegSeq TSS: 2999918
# Guillaume TSS: [3000039, 2999918, 3000254]
# Differences in start sites: [121, 0, 336]
#
# mscK is in the operon list.
# RegSeq TSS: 486492
# Guillaume TSS: [486489]
# Differences in start sites: [-3]
#
# mscS is in the operon list.
# RegSeq TSS: 3069871
# Guillaume TSS: [3069871, 3070054, 3070248]
# Differences in start sites: [0, 183, 377]
#
# ynaI is in the operon list.
# RegSeq TSS: 1395973
# Guillaume TSS: [1395972]
# Differences in start sites: [-1]
#
# ybdG is in the operon list.
# RegSeq TSS: 604684
# Guillaume TSS: [604683]
# Differences in start sites: [-1]
#
# hicB is in the operon list for operon hicAB.
# RegSeq TSS: 1509221
# Guillaume TSS: [1509129, 1509275, 1509221]
# Differences in start sites: [-92, 54, 0]
#
# arcB is in the operon list.
# RegSeq TSS: 3353049
# Guillaume TSS: [3353048]
# Differences in start sites: [-1]
#
# minC is in the operon list for operon minCDE.
# RegSeq TSS: 1226139
# Guillaume TSS: [1226139, 1226433]
# Differences in start sites: [0, 294]
#
# ybeZ is in the operon list for operon ybeZYX-lnt.
# RegSeq TSS: 693469
# Guillaume TSS: [693693, 693632, 693469, 693429]
# Differences in start sites: [224, 163, 0, -40]
#
# ydjA is in the operon list for operon ydjA-selD-topB.
# RegSeq TSS: 1848700
# Guillaume TSS: [1848700]
# Differences in start sites: [0]
#
# yggW is in the operon list for operon yggSTU-rdgB-yggW.
# RegSeq TSS: 3096620
# Guillaume TSS: [3098542, 3098617, 3095060, 3098520, 3094690]
# Differences in start sites: [1922, 1997, -1560, 1900, -1930]
#
# acuI is in the operon list for operon yhdH.
# RegSeq TSS: 3403446
# Guillaume TSS: [3403280, 3403446, 3403230, 3403377]
# Differences in start sites: [-166, 0, -216, -69]
#
# yehU is in the operon list for operon yehUT.
# RegSeq TSS: 2214673
# Guillaume TSS: [2214671]
# Differences in start sites: [-2]
#
# yehT is in the operon list for operon yehUT.
# RegSeq TSS: 2212969
# Guillaume TSS: [2214671]
# Differences in start sites: [1702]
#
# ybiO is in the operon list.
# RegSeq TSS: 845736
# Guillaume TSS: [845664, 845736, 845509]
# Differences in start sites: [-72, 0, -227]
#
# mscL is in the operon list.
# RegSeq TSS: 3438001
# Guillaume TSS: [3437990]
# Differences in start sites: [-11]
#
# zapB is in the operon list.
# RegSeq TSS: 4118427
# Guillaume TSS: [4118479, 4118427, 4118386, 4118241, 4118171]
# Differences in start sites: [52, 0, -41, -186, -256]
#
# WaaA-coaD is in the operon list for operon waaA-coaD.
# RegSeq TSS: 3808516
# Guillaume TSS: [3808509, 3808256, 3810770]
# Differences in start sites: [-7, -260, 2254]
#
# coaA is in the operon list.
# RegSeq TSS: 4175107
# Guillaume TSS: [4175204, 4175106]
# Differences in start sites: [97, -1]
#
# yjjJ is in the operon list.
# RegSeq TSS: 4621716
# Guillaume TSS: [4621657, 4621739, 4621716]
# Differences in start sites: [-59, 23, 0]
#
# groSL is in the operon list.
# RegSeq TSS: 4370616
# Guillaume TSS: [4370648, 4370616]
# Differences in start sites: [32, 0]
#
# pyrLBI is in the operon list.
# RegSeq TSS: 4472553
# Guillaume TSS: [4472978, 4472550, 4472745]
# Differences in start sites: [425, -3, 192]
#
# rplKAJL-rpoBC is in the operon list.
# RegSeq TSS: 4178354
# Guillaume TSS: [4178391, 4178354, 4178440, 4189903, 4190028]
# Differences in start sites: [37, 0, 86, 11549, 11674]
#
# yodB is in the operon list.
# RegSeq TSS: 2042294
# Guillaume TSS: [2042176, 2042294, 2042261]
# Differences in start sites: [-118, 0, -33]
#
# atpIBEFHAGDC is in the operon list.
# RegSeq TSS: 3922525
# Guillaume TSS: [3922766, 3922887, 3922720, 3922524]
# Differences in start sites: [241, 362, 195, -1]
#
# msyB is in the operon list.
# RegSeq TSS: 1114213
# Guillaume TSS: [1114212]
# Differences in start sites: [-1]
#
# ndk is in the operon list.
# RegSeq TSS: 2644913
# Guillaume TSS: [2645212, 2644948, 2644913]
# Differences in start sites: [299, 35, 0]
#
# thrLABC is in the operon list.
# RegSeq TSS: 148
# Guillaume TSS: [113, 38, 147]
# Differences in start sites: [-35, -110, -1]
#
# tig is in the operon list.
# RegSeq TSS: 454993
# Guillaume TSS: [455122, 454715, 454834, 454993, 454664]
# Differences in start sites: [129, -278, -159, 0, -329]
#
# tff-rpsB-tsf is in the operon list.
# RegSeq TSS: 189712
# Guillaume TSS: [191794, 189548, 189712, 191941, 189639]
# Differences in start sites: [2082, -164, 0, 2229, -73]
#
# poxB is in the operon list for operon poxB-ltaE-ybjT.
# RegSeq TSS: 911076
# Guillaume TSS: [911075]
# Differences in start sites: [-1]
#
# rspA is in the operon list for operon rspAB.
# RegSeq TSS: 1655186
# Guillaume TSS: [1655334]
# Differences in start sites: [148]
#
# mscM is in the operon list for operon psd-mscM.
# RegSeq TSS: 4390638
# Guillaume TSS: [4390439, 4390663, 4390636]
# Differences in start sites: [-199, 25, -2]
#
# arcA is in the operon list.
# RegSeq TSS: 4640508
# Guillaume TSS: [4640332, 4640801, 4640372, 4640595, 4640420, 4640508, 4640660]
# Differences in start sites: [-176, 293, -136, 87, -88, 0, 152]
#
# tar is in the operon list for operon tar-tap-cheRBYZ.
# RegSeq TSS: 1972716
# Guillaume TSS: [1972715]
# Differences in start sites: [-1]
#
# dpiBA is in the operon list.
# RegSeq TSS: 652172
# Guillaume TSS: [651984]
# Differences in start sites: [-188]
#
# araAB is in the operon list for operon araBAD.
# RegSeq TSS: 70075
# Guillaume TSS: [70075]
# Differences in start sites: [0]
#
# araC is in the operon list.
# RegSeq TSS: 70241
# Guillaume TSS: [70221, 70387]
# Differences in start sites: [-20, 146]
#
# xylF is in the operon list for operon xylFGHR.
# RegSeq TSS: 3731069
# Guillaume TSS: [3731069]
# Differences in start sites: [0]
#
# xylA is in the operon list for operon xylAB.
# RegSeq TSS: 3730807
# Guillaume TSS: [3730807, 3730832]
# Differences in start sites: [0, 25]
#
# dicA is in the operon list.
# RegSeq TSS: 1647934
# Guillaume TSS: [1647930]
# Differences in start sites: [-4]
#
# dicC is in the operon list for operon dicC-ydfXW.
# RegSeq TSS: 1647876
# Guillaume TSS: [1648328, 1647876]
# Differences in start sites: [452, 0]
#
# dicB is in the operon list for operon dicB-ydfDE-insD-intQ.
# RegSeq TSS: 1649597
# Guillaume TSS: [1649597, 1649112, 1649454]
# Differences in start sites: [0, -485, -143]
#
# ompR is in the operon list for operon ompR-envZ.
# RegSeq TSS: 3536707
# Guillaume TSS: [3536639, 3536775, 3536949, 3536707, 3536619, 3536685, 3536755]
# Differences in start sites: [-68, 68, 242, 0, -88, -22, 48]
#
# xapAB is in the operon list.
# RegSeq TSS: 2524910
# Guillaume TSS: [2525372, 2524910]
# Differences in start sites: [462, 0]
#
# ilvC is in the operon list.
# RegSeq TSS: 3957912
# Guillaume TSS: [3957912]
# Differences in start sites: [0]
#
# asnA is in the operon list.
# RegSeq TSS: 3927129
# Guillaume TSS: [3926791, 3926720, 3927129]
# Differences in start sites: [-338, -409, 0]
#
# idnK is in the operon list.
# RegSeq TSS: 4494597
# Guillaume TSS: [4494597]
# Differences in start sites: [0]
#
# dinJ is in the operon list for operon dinJ-yafQ.
# RegSeq TSS: 246533
# Guillaume TSS: [246675, 246615]
# Differences in start sites: [142, 82]
#
# yjiY is in the operon list.
# RegSeq TSS: 4591367
# Guillaume TSS: [4591347, 4591656]
# Differences in start sites: [-20, 289]
#
# motAB-cheAW is in the operon list.
# RegSeq TSS: 1977302
# Guillaume TSS: [1977300]
# Differences in start sites: [-2]
#
# ftsK is in the operon list.
# RegSeq TSS: 933138
# Guillaume TSS: [932929, 933181, 933218, 933135]
# Differences in start sites: [-209, 43, 80, -3]
#
# cra is in the operon list.
# RegSeq TSS: 87969
# Guillaume TSS: [87969, 87733, 87947, 87847]
# Differences in start sites: [0, -236, -22, -122]
#
# uvrD is in the operon list.
# RegSeq TSS: 3997907
# Guillaume TSS: [3997907, 3997971, 3997751]
# Differences in start sites: [0, 64, -156]
#
# adiY is in the operon list.
# RegSeq TSS: 4338042
# Guillaume TSS: [4338042, 4338214, 4337995, 4338021]
# Differences in start sites: [0, 172, -47, -21]
#
# znuCB is in the operon list.
# RegSeq TSS: 1942634
# Guillaume TSS: [1942590, 1942558, 1942634, 1942411]
# Differences in start sites: [-44, -76, 0, -223]
#
# znuA is in the operon list.
# RegSeq TSS: 1942661
# Guillaume TSS: [1942612, 1942646]
# Differences in start sites: [-49, -15]
#
# zupT is in the operon list.
# RegSeq TSS: 3182433
# Guillaume TSS: [3182422, 3182450]
# Differences in start sites: [-11, 17]
#
# pitA is in the operon list.
# RegSeq TSS: 3637612
# Guillaume TSS: [3637522, 3637612, 3637396, 3637578]
# Differences in start sites: [-90, 0, -216, -34]
#
# ecnB is in the operon list for operon ecnAB.
# RegSeq TSS: 4376509
# Guillaume TSS: [4375964]
# Differences in start sites: [-545]
#
# leuABCD is in the operon list for operon leuLABCD.
# RegSeq TSS: 83735
# Guillaume TSS: [83728, 83894]
# Differences in start sites: [-7, 159]
#
# Found no operon for genes ["yedJ", "yicI", "rumB", "yfhG", "holC", "rapA", "maoP"]

# %% [markdown]
# Let's have a look at all the observed differences.

# %%
Plots.scatter(positions, differences, label=:none, xlabel="Position", ylabel="difference in TSS")
# Out:
# <!DOCTYPE html>
# <html>
#     <head>
#         <title>Plots.jl</title>
#         <meta http-equiv="content-type" content="text/html; charset=UTF-8">
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#     </head>
#     <body>
#             <div id="670d8d4b-e3d7-42fa-996a-4580571dd85a" style="width:600px;height:400px;"></div>
#     <script>
#     PLOT = document.getElementById('670d8d4b-e3d7-42fa-996a-4580571dd85a');
#     Plotly.plot(PLOT, [
#     {
#         "xaxis": "x1",
#         "colorbar": {
#             "title": ""
#         },
#         "yaxis": "y1",
#         "x": [
#             4.085961e6,
#             2.927935e6,
#             2.927935e6,
#             2.928103e6,
#             2.928035e6,
#             2.18545e6,
#             321511.0,
#             321481.0,
#             321537.0,
#             1.996851e6,
#             3.155384e6,
#             911075.0,
#             3.350559e6,
#             3.350497e6,
#             4.269355e6,
#             4.474096e6,
#             4.473676e6,
#             1.523276e6,
#             1.523094e6,
#             1.523157e6,
#             285207.0,
#             285271.0,
#             285350.0,
#             2.303797e6,
#             2.303851e6,
#             1.116709e6,
#             2.876107e6,
#             2.876536e6,
#             3.235904e6,
#             2.009802e6,
#             2.009515e6,
#             2.009631e6,
#             2.585567e6,
#             2.230395e6,
#             2.23046e6,
#             2.230485e6,
#             4.085961e6,
#             197586.0,
#             197730.0,
#             197487.0,
#             208711.0,
#             197821.0,
#             197883.0,
#             197586.0,
#             197730.0,
#             197487.0,
#             208711.0,
#             197821.0,
#             197883.0,
#             1.237284e6,
#             2.212226e6,
#             2.265961e6,
#             2.266164e6,
#             2.266214e6,
#             1.734145e6,
#             1.734206e6,
#             1.734381e6,
#             1.734357e6,
#             4.122348e6,
#             4.12231e6,
#             1.223096e6,
#             1.907084e6,
#             1.907139e6,
#             1.907509e6,
#             795065.0,
#             794649.0,
#             1.01846e6,
#             1.018721e6,
#             1.018323e6,
#             444822.0,
#             444555.0,
#             1.950636e6,
#             1.950521e6,
#             1.95076e6,
#             852713.0,
#             852626.0,
#             889992.0,
#             889938.0,
#             889941.0,
#             2.926272e6,
#             2.870618e6,
#             2.870686e6,
#             220072.0,
#             220022.0,
#             220386.0,
#             220265.0,
#             2.082724e6,
#             3.000039e6,
#             2.999918e6,
#             3.000254e6,
#             486489.0,
#             3.069871e6,
#             3.070054e6,
#             3.070248e6,
#             1.395972e6,
#             604683.0,
#             1.509129e6,
#             1.509275e6,
#             1.509221e6,
#             3.353048e6,
#             1.226139e6,
#             1.226433e6,
#             693693.0,
#             693632.0,
#             693469.0,
#             693429.0,
#             1.8487e6,
#             3.098542e6,
#             3.098617e6,
#             3.09506e6,
#             3.09852e6,
#             3.09469e6,
#             3.40328e6,
#             3.403446e6,
#             3.40323e6,
#             3.403377e6,
#             2.214671e6,
#             2.214671e6,
#             845664.0,
#             845736.0,
#             845509.0,
#             3.43799e6,
#             4.118479e6,
#             4.118427e6,
#             4.118386e6,
#             4.118241e6,
#             4.118171e6,
#             3.808509e6,
#             3.808256e6,
#             3.81077e6,
#             4.175204e6,
#             4.175106e6,
#             4.621657e6,
#             4.621739e6,
#             4.621716e6,
#             4.370648e6,
#             4.370616e6,
#             4.472978e6,
#             4.47255e6,
#             4.472745e6,
#             4.178391e6,
#             4.178354e6,
#             4.17844e6,
#             4.189903e6,
#             4.190028e6,
#             2.042176e6,
#             2.042294e6,
#             2.042261e6,
#             3.922766e6,
#             3.922887e6,
#             3.92272e6,
#             3.922524e6,
#             1.114212e6,
#             2.645212e6,
#             2.644948e6,
#             2.644913e6,
#             113.0,
#             38.0,
#             147.0,
#             455122.0,
#             454715.0,
#             454834.0,
#             454993.0,
#             454664.0,
#             191794.0,
#             189548.0,
#             189712.0,
#             191941.0,
#             189639.0,
#             911075.0,
#             1.655334e6,
#             4.390439e6,
#             4.390663e6,
#             4.390636e6,
#             4.640332e6,
#             4.640801e6,
#             4.640372e6,
#             4.640595e6,
#             4.64042e6,
#             4.640508e6,
#             4.64066e6,
#             1.972715e6,
#             651984.0,
#             70075.0,
#             70221.0,
#             70387.0,
#             3.731069e6,
#             3.730807e6,
#             3.730832e6,
#             1.64793e6,
#             1.648328e6,
#             1.647876e6,
#             1.649597e6,
#             1.649112e6,
#             1.649454e6,
#             3.536639e6,
#             3.536775e6,
#             3.536949e6,
#             3.536707e6,
#             3.536619e6,
#             3.536685e6,
#             3.536755e6,
#             2.525372e6,
#             2.52491e6,
#             3.957912e6,
#             3.926791e6,
#             3.92672e6,
#             3.927129e6,
#             4.494597e6,
#             246675.0,
#             246615.0,
#             4.591347e6,
#             4.591656e6,
#             1.9773e6,
#             932929.0,
#             933181.0,
#             933218.0,
#             933135.0,
#             87969.0,
#             87733.0,
#             87947.0,
#             87847.0,
#             3.997907e6,
#             3.997971e6,
#             3.997751e6,
#             4.338042e6,
#             4.338214e6,
#             4.337995e6,
#             4.338021e6,
#             1.94259e6,
#             1.942558e6,
#             1.942634e6,
#             1.942411e6,
#             1.942612e6,
#             1.942646e6,
#             3.182422e6,
#             3.18245e6,
#             3.637522e6,
#             3.637612e6,
#             3.637396e6,
#             3.637578e6,
#             4.375964e6,
#             83728.0,
#             83894.0
#         ],
#         "showlegend": false,
#         "mode": "markers",
#         "name": "",
#         "zmin": null,
#         "legendgroup": "",
#         "marker": {
#             "symbol": "circle",
#             "color": "rgba(0, 154, 250, 1.000)",
#             "line": {
#                 "color": "rgba(0, 0, 0, 1.000)",
#                 "width": 1
#             },
#             "size": 8
#         },
#         "zmax": null,
#         "y": [
#             94.0,
#             -100.0,
#             -100.0,
#             68.0,
#             0.0,
#             -1.0,
#             0.0,
#             -30.0,
#             26.0,
#             -16.0,
#             122.0,
#             1755.0,
#             55.0,
#             -7.0,
#             0.0,
#             0.0,
#             -420.0,
#             0.0,
#             -182.0,
#             -119.0,
#             -143.0,
#             -79.0,
#             0.0,
#             0.0,
#             54.0,
#             0.0,
#             -440.0,
#             -11.0,
#             -11.0,
#             26.0,
#             -261.0,
#             -145.0,
#             -3.0,
#             0.0,
#             65.0,
#             90.0,
#             4602.0,
#             560.0,
#             704.0,
#             461.0,
#             11685.0,
#             795.0,
#             857.0,
#             -235.0,
#             -91.0,
#             -334.0,
#             10890.0,
#             0.0,
#             62.0,
#             -1.0,
#             -15.0,
#             -253.0,
#             -50.0,
#             0.0,
#             -212.0,
#             -151.0,
#             24.0,
#             0.0,
#             -6.0,
#             -44.0,
#             -1.0,
#             -2.0,
#             53.0,
#             423.0,
#             421.0,
#             5.0,
#             130.0,
#             391.0,
#             -7.0,
#             1074.0,
#             807.0,

# %% [markdown]
# It seems like we found many nearly matching TSSs.

# %% [markdown]
# Seems like we found 79 TSSs which are within 10 bp of the RegSeq TSS.

# %%
exact_match
# Out:
# 79-element Array{Int64,1}:
#  2928035
#  2185450
#   321511
#  3350497
#  4269355
#  4474096
#  1523276
#   285350
#  2303797
#  1116709
#  2585567
#  2230395
#   197821
#        ⋮
#  2524910
#  3957912
#  3927129
#  4494597
#  1977300
#   933135
#    87969
#  3997907
#  4338042
#  1942634
#  3637612
#    83728

# %% [markdown]
# Let's check how many of those TSS were observed to be active.

# %%
active_close_df = df[map(x->x in exact_match, df.new_tss_position) .* (df.active .== "active"), :]
# Out:
# 21×10 DataFrame. Omitted printing of 7 columns
# │ Row │ tss_name                        │ tss_strand │ tss_position │
# │     │ String                          │ String     │ Int64        │
# ├─────┼─────────────────────────────────┼────────────┼──────────────┤
# │ 1   │ TSS_14751_wanner                │ +          │ 3806532      │
# │ 2   │ TSS_353_regulondb               │ -          │ 83728        │
# │ 3   │ TSS_17053_storz_regulondb       │ +          │ 4368639      │
# │ 4   │ TSS_9945_storz_wanner_regulondb │ -          │ 2642935      │
# │ 5   │ TSS_16340_storz_regulondb       │ +          │ 4176377      │
# │ 6   │ TSS_785_regulondb               │ +          │ 189712       │
# │ 7   │ TSS_16903_regulondb             │ -          │ 4336065      │
# │ 8   │ TSS_8330_wanner                 │ -          │ 2183472      │
# │ 9   │ TSS_3578_storz_regulondb        │ +          │ 932358       │
# │ 10  │ TSS_15199_wanner                │ -          │ 3920547      │
# │ 11  │ TSS_17479_wanner                │ -          │ 4470573      │
# │ 12  │ TSS_18061_regulondb             │ +          │ 4619739      │
# │ 13  │ TSS_7564_storz_regulondb        │ -          │ 1975324      │
# │ 14  │ TSS_1801_storz_regulondb        │ +          │ 454217       │
# │ 15  │ TSS_4752_wanner_regulondb       │ -          │ 1225362      │
# │ 16  │ TSS_7553_storz                  │ -          │ 1970739      │
# │ 17  │ TSS_6644_regulondb              │ +          │ 1732381      │
# │ 18  │ TSS_4_wanner                    │ +          │ 147          │
# │ 19  │ TSS_6311_regulondb              │ +          │ 1645954      │
# │ 20  │ TSS_18121_regulondb             │ -          │ 4638531      │
# │ 21  │ TSS_16715_storz_regulondb       │ +          │ 4267378      │

# %% [markdown]
# Only 21?

# %% [markdown]
# Finally, let's see for which TSSs we have data in the mutagenesis file. Therefore we check which entries have the same TSS as the ones we extracted above. (here we can look either at all or only at active ones)

# %%
#inds = map(x-> x in active_close_df.new_tss_position, df2.new_tss_position)
inds = map(x-> x in exact_match, df2.new_tss_position)
inds = map(x->begin
        if ismissing(x)
               false
        else
            x
           end
       end,
    inds);

# %%
matching_tss = df2[inds, :]
# Out:
# 1079×18 DataFrame. Omitted printing of 17 columns
# │ Row  │ name                                                │
# │      │ String                                              │
# ├──────┼─────────────────────────────────────────────────────┤
# │ 1    │ TSS_8330_wanner,2183472,-_scrambled5-15             │
# │ 2    │ TSS_7564_storz_regulondb,1975324,-_scrambled10-20   │
# │ 3    │ TSS_3400_regulondb,889164,-_scrambled15-25          │
# │ 4    │ TSS_3076_wanner,793872,-_scrambled5-15              │
# │ 5    │ TSS_15537_storz_regulondb,3995930,+_scrambled30-40  │
# │ 6    │ TSS_7290_storz,1905108,-_scrambled15-25             │
# │ 7    │ TSS_3076_wanner,793872,-_scrambled100-110           │
# │ 8    │ TSS_15199_wanner,3920547,-_scrambled40-50           │
# │ 9    │ TSS_6644_regulondb,1732381,+_scrambled105-115       │
# │ 10   │ TSS_8604_storz_regulondb,2264236,+_scrambled25-35   │
# ⋮
# │ 1069 │ TSS_16075_storz_regulondb,4120371,-_scrambled45-55  │
# │ 1070 │ TSS_13689_regulondb,3534729,-_scrambled110-120      │
# │ 1071 │ TSS_785_regulondb,189712,+_scrambled20-30           │
# │ 1072 │ TSS_3959_wanner,1017546,-_scrambled125-135          │
# │ 1073 │ TSS_8414_wanner,2212693,-_scrambled105-115          │
# │ 1074 │ TSS_1801_storz_regulondb,454217,+_scrambled55-65    │
# │ 1075 │ TSS_16340_storz_regulondb,4176377,+_scrambled75-85  │
# │ 1076 │ TSS_3959_wanner,1017546,-_scrambled35-45            │
# │ 1077 │ TSS_18121_regulondb,4638531,-_scrambled100-110      │
# │ 1078 │ TSS_7564_storz_regulondb,1975324,-_scrambled125-135 │
# │ 1079 │ TSS_3959_wanner,1017546,-_scrambled105-115          │

# %%
matched_tss_list = matching_tss.new_tss_position |> unique
# Out:
# 40-element Array{Int64,1}:
#  2185450
#  1977300
#   889941
#   794649
#  3997907
#  1907084
#  3922524
#  1734357
#  2266214
#  1942634
#  2214671
#  2928035
#  1395972
#        ⋮
#    87969
#   486489
#  3069871
#  1972715
#  2644913
#  4472550
#  1226139
#  3808509
#  4640508
#  2999918
#  3536707
#   189712

# %% [markdown]
# I don't fully understand why there are only scrambles for 46 out of 79. However, if the only the active ones are considered above, then we find scrambles for all TSSs.

# %%
p = plot(layout = (length(matched_tss_list), 1), size = (300, 300*length(matched_tss_list)))
for (i, tss) in enumerate(matched_tss_list)
    x = matching_tss[matching_tss.new_tss_position .== tss, :scramble_start]
    y = matching_tss[matching_tss.new_tss_position .== tss, :relative_exp]
    tss_name = unique(matching_tss[matching_tss.new_tss_position .== tss, :tss_name])[1]
    operon = df[df.tss_name .== tss_name, :operon][1]
    scatter!(p[i, 1], x, y, title=operon, label=:none)
end
savefig(p, "test")
